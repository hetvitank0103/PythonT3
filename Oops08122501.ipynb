# %%
class Name:
    def fun(self):
        self.name='abc'
        self.age=18
    def display(self):
        print(self.name)
        print(self.age)
N=Name()
N.fun()
N.display()
# Out:
# abc
# 18

# %%
class Name:
    def fun():
        name='abc'
        age=18
    def display():
        print(name)
        print(age)
N=Name()
N.fun()
N.display()
#jya jya self lakhyu che tya obj avse means bhale kai 
#perameter ma pass nai karayu but obj banavo to method ma obj jai as perameter so it's needed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-eb62de951a30> in <module>
#       7         print(age)
#       8 N=Name()
# ----> 9 N.fun()
#      10 N.display()
#      11 #jya jya self lakhyu che tya obj avse means bhale kai
#
# TypeError: fun() takes 0 positional arguments but 1 was given

# %%
class Name:
    def fun(self):
        name='abc'
        age=18
    def display(self):
        print(self.name)
        print(self.age)
N=Name()
N.fun()
N.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-50014a8a494d> in <module>
#       8 N=Name()
#       9 N.fun()
# ---> 10 N.display()
#
# <ipython-input-3-50014a8a494d> in display(self)
#       4         age=18
#       5     def display(self):
# ----> 6         print(self.name)
#       7         print(self.age)
#       8 N=Name()
#
# AttributeError: 'Name' object has no attribute 'name'

# %%
#obj banavo tyare construter call thai and delete karo tyare deconstructer call thai
class Name:
    def __init__(self,name,age=18):
        #like constructor 
        self.name=name
        self.age=age
        print("Construter")
    def display(self):
        print(self.name)
        print(self.age)
    def __del__(self):
        print("destructer called")
N=Name('Hetvi')
N.display()
del N
# Out:
# Construter
# Hetvi
# 18
# destructer called

# %%
#pela no delete thai reconstract thai
class Name:
    def __init__(self,name,age=18):
        #like constructor 
        self.name=name
        self.age=age
        print("Construter")
    def display(self):
        print(self.name)
        print(self.age)
    def __del__(self):
        print("destructer called")
N=Name('Hetvi')
N.display()
# Out:
# Construter
# Hetvi
# 18

# %%
class Name:
    ba='aaaa'
    def __init__(self,name,age=18):
        #like constructor 
        self.name=name
        self.age=age
        print("Construter")
    def display(self):
        print(self.name)
        print(self.age)
    def __del__(self):
        print("destructer called")
N=Name('Hetvi')
N.display()
print(N.ba)
# Out:
# Construter
# destructer called
# Hetvi
# 18
# aaaa

# %%
class Name:
    ba='aaaa'
    def __init__(self,name,age=18):
        #like constructor 
        self.name=name
        self.age=age
        print("Construter")
    def display(self):
        print(self.name)
        print(self.age)
    def __del__(self):
        print("destructer called")
N=Name('Hetvi')
N.display()
print(N.ba)
n=Name('Aesha')
n.display()
n.ba='ja'
print(n.ba)
print(N.ba)
Name.ba='Yes'#last j obj vapaeyo ae  anigyo
print(n.ba)
print(N.ba)
#can not change anythind from outside of class j che ae  j obj che emaj thai che
# Out:
# Construter
# destructer called
# Hetvi
# 18
# aaaa
# Construter
# Aesha
# 18
# ja
# aaaa
# ja
# Yes

# %%
import sys
sys.path
# Out:
# ['D:\\Hetvip',
#  'C:\\ProgramData\\Anaconda3\\python38.zip',
#  'C:\\ProgramData\\Anaconda3\\DLLs',
#  'C:\\ProgramData\\Anaconda3\\lib',
#  'C:\\ProgramData\\Anaconda3',
#  '',
#  'C:\\Users\\LJENG\\AppData\\Roaming\\Python\\Python38\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\LJENG\\.ipython']

# %%
import sys
sys.path.append('D:')
sys.path
# Out:
# ['D:\\Hetvip',
#  'C:\\ProgramData\\Anaconda3\\python38.zip',
#  'C:\\ProgramData\\Anaconda3\\DLLs',
#  'C:\\ProgramData\\Anaconda3\\lib',
#  'C:\\ProgramData\\Anaconda3',
#  '',
#  'C:\\Users\\LJENG\\AppData\\Roaming\\Python\\Python38\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\LJENG\\.ipython',
#  'D:']

# %%
class A:
    a=1
    def __init__(self):
        self.a=A.a
        self.a+=1
        A.a=self.a
        A.a+=1
x=A()
print(x.a)
print(A.a)
# Out:
# 2
# 3

# %%
class A:
    a=1
    def __init__(self):
        self.a=A.a
        self.a+=1
        A.a=self.a
        A.a+=1
x=A()
y=A()
print(x.a)
print(A.a)
# Out:
# 2
# 5

# %%
#recursion
class Name:
    def __init__(self,name,age=18):
        #like constructor 
        self.name=name
        self.age=age
        self.display()
        print("Construter")
    def display(self):
        print(self.name)
        print(self.age)
    def __del__(self):
        print("destructer called")
N=Name('Hetvi')
# Out:
# Hetvi
# 18
# Construter
# destructer called

# %%
#ATM code
class Atm:
    def __init__(self):
        self.pin=''
        self.balance=20000
        self.count=0
        self.menu()
    def menu(self):
        user=input(''' 
        1.ENTER 1 FOR CREATE PIN
        2.ENTER 2 FOR CHANING PIN
        3.ENTER 3 FOR CHACKING BALANCE
        4.ENTER 4 FOR WITDRAW
        5.ENTER ANTYTING ELSE TO EXSIT.''')
        if user=='1':
            self.createpin()
        elif user=='2':
            self.changepin()
        elif user=='3':
            self.checkbalance()
        elif user=='4':
            self.withdraw()
        else:
            print("THANK YOU VISITING!")
    def createpin(self):
        if self.count==0:
            self.pin=input("Enter 4 digi pin")
            print("pin creted successfully")
        else:
            print("pin already genrated")
        self.count+=1
        self.menu()
    def changepin(self):
        pin=input("Enter your current pin")
        if(pin==self.pin):
            self.pin=input("Enter new 4 digi pin")
            print("pin creted successfully")
        else:
            print("please Enter correct pin")
        self.menu()
    def checkbalance(self):
        pin=input("Enter your current pin")
        if(pin==self.pin):
            print(f"Yor balance is{self.balance}")
        else:
            print("please Enter correct pin")
        self.menu()
    def withdraw(self):
        pin=input("Enter your current pin")
        if(pin==self.pin):
            bal=int(input("Enter amount to withdsraw: "))
            if bal <=self.balance:
                self.balance-=bal
                print(f"Amount {bal} withdraw successfully")
            else:
                print("insufficiant balance")
        else:
            print("please Enter correct pin")
        self.menu()
a=Atm()
# Out:
#
#         1.ENTER 1 FOR CREATE PIN
#         2.ENTER 2 FOR CHANING PIN
#         3.ENTER 3 FOR CHACKING BALANCE
#         4.ENTER 4 FOR WITDRAW
#         5.ENTER ANTYTING ELSE TO EXSIT.1
# Enter 4 digi pin1111
# pin creted successfully
#
#         1.ENTER 1 FOR CREATE PIN
#         2.ENTER 2 FOR CHANING PIN
#         3.ENTER 3 FOR CHACKING BALANCE
#         4.ENTER 4 FOR WITDRAW
#         5.ENTER ANTYTING ELSE TO EXSIT.1
# pin already genrated
#
#         1.ENTER 1 FOR CREATE PIN
#         2.ENTER 2 FOR CHANING PIN
#         3.ENTER 3 FOR CHACKING BALANCE
#         4.ENTER 4 FOR WITDRAW
#         5.ENTER ANTYTING ELSE TO EXSIT.h
# THANK YOU VISITING!

# %%
#ATM code
class Atm:
    def __init__(self):
        self.pin=''
        self.balance=20000
        self.menu()
    def menu(self):
        user=input(''' 
        1.ENTER 1 FOR CREATE PIN
        2.ENTER 2 FOR CHANING PIN
        3.ENTER 3 FOR CHACKING BALANCE
        4.ENTER 4 FOR WITDRAW
        5.ENTER ANTYTING ELSE TO EXSIT.''')
        if user=='1':
            self.createpin()
        elif user=='2':
            self.changepin()
        elif user=='3':
            self.checkbalance()
        elif user=='4':
            self.withdraw()
        else:
            print("THANK YOU VISITING!")
    def createpin(self):
        self.pin=input("Enter 4 digi pin")
        print("pin creted successfully")
        self.menu()
    def changepin(self):
        pin=input("Enter your current pin")
        if(pin==self.pin):
            self.pin=input("Enter new 4 digi pin")
            print("pin creted successfully")
        else:
            print("please Enter correct pin")
        self.menu()
    def checkbalance(self):
        pin=input("Enter your current pin")
        if(pin==self.pin):
            print(f"Yor balance is{self.balance}")
        else:
            print("please Enter correct pin")
        self.menu()
    def withdraw(self):
        pin=input("Enter your current pin")
        if(pin==self.pin):
            bal=int(input("Enter amount to withdsraw: "))
            if bal <=self.balance:
                self.balance-=bal
                print(f"Amount {bal} withdraw successfully")
            else:
                print("insufficiant balance")
        else:
            print("please Enter correct pin")
        self.menu()
a=Atm()
# Out:
#
#         1.ENTER 1 FOR CREATE PIN
#         2.ENTER 2 FOR CHANING PIN
#         3.ENTER 3 FOR CHACKING BALANCE
#         4.ENTER 4 FOR WITDRAW
#         5.ENTER ANTYTING ELSE TO EXSIT.g
# THANK YOU VISITING!

# %%
# htttps://dhruvpython.pythonanywhere.com
