# %%
# %%writefile Jenisha.txt
# Hello welcome
# Out:
# Overwriting Jenisha.txt

# %%
f=open('sample.txt','w')
f.write('B3 is Best')
f.close()

# %%
f=open('Jenisha.txt','w')
f.write('Hello \nwelcome')
f.close()

# %%
f=open('sample.txt','a')
f.writelines(['hello\n','welcomeback\n','hi'])
f.close()

# %%
f=open('sample.txt','w')
f.writelines(['1 hello\n','2 hello\n','3 hello\n','4 hello'])
f.close()

# %%
f=open('sample.txt')
print(f.read(3))
print('hii',f.read())
f.close()
# Out:
# 1 h
# hii ello
# 2 hello
# 3 hello
# 4 hello

# %%
f=open("sample.txt")
data=(f.readlines())
f.close()
f=open('New.txt','w')
f.writelines(data)
f.close()
f=open('New.txt')
print(f.read())
f.close()
# Out:
# 1 hello
# 2 hello
# 3 hello
# 4 hello

# %%
f=open("New.txt",'r+')
print(f.read())
f.write('Jenisha')
f.close()
# Out:
# 1 hello
# 2 hello
# 3 hello
# 4 helloJenisha

# %%
f=open("New.txt",'r+')
f.write('Jenisha')
print(f.read())
f.close()
# Out:
# 2 hello
# 3 hello
# 4 helloJenishaJenisha

# %%
f=open("sample.txt",'w+')
f.write('Jenisha')
print(f.tell())
f.seek(3)
print(f.read())
f.close()
# Out:
# 7
# isha

# %%
f=open("sample.txt",'a+')
f.write('Jiya')
print(f.read())
f.seek(1)
print(f.read())
f.close()
# Out:
# enishaJiyaJiya

# %%
 f=open('New.txt')
print(f.tell())
f.seek(0,1)
print(f.tell())
f.close()
# Out:
# 0
# 0

# %%
with open('Jenisha.txt','a+') as f:
    print(f.mode)
    print(f.name)
    print(f.closed)
    print(f.readable())
    print(f.writeable())
# Out:
# a+
# Jenisha.txt
# False
# True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-306b78e92a96> in <module>
#       4     print(f.closed)
#       5     print(f.readable())
# ----> 6     print(f.writeable())
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'writeable'

# %%
f=open("mbox-short.txt")
d={}
for i in f:
    if(i.startswith("From ")):
        print(i.split()[1])
        for j in i.split():
        
print(d)
# Out:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
# ...
