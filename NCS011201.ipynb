# %%
s="hetvi is best"
s='hetvi'
iff s:
    print(s)
# Out:
#   File "<ipython-input-1-3dd66aee70ca>", line 3
#     iff s:
#         ^
# SyntaxError: invalid syntax

# %%
Class Hetvi:
# Out:
#   File "<ipython-input-2-b10248e7facc>", line 1
#     Class Hetvi:
#           ^
# SyntaxError: invalid syntax

# %%
if 2==2
# Out:
#   File "<ipython-input-3-e0363f5038cd>", line 1
#     if 2==2
#            ^
# SyntaxError: invalid syntax

# %%
for i in range(1,11):
# Out:
#   File "<ipython-input-4-43b42b362104>", line 1
#     for i in range(1,11):
#                          ^
# SyntaxError: unexpected EOF while parsing

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bca0e2660b9f> in <module>
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
l=[1,2,3,3]
print(l[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-c42a420a08b2> in <module>
#       1 l=[1,2,3,3]
# ----> 2 print(l[5])
#
# IndexError: list index out of range

# %%
f=open('coffee.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-d107732f81e3> in <module>
# ----> 1 f=open('coffee.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'coffee.txt'

# %%
import coffeelover as c
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-256d2737c68c> in <module>
# ----> 1 import coffeelover as c
#
# ModuleNotFoundError: No module named 'coffeelover'

# %%
d={'1':2,'3':3}
d[10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-1b57905bc072> in <module>
#       1 d={'1':2,'3':3}
# ----> 2 d[10]
#
# KeyError: 10

# %%
s=3+'g'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-b6ef6be68355> in <module>
# ----> 1 s=3+'g'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
int hetvi09
# Out:
#   File "<ipython-input-11-045ee73ba870>", line 1
#     int hetvi09
#         ^
# SyntaxError: invalid syntax

# %%
int('hetvi10')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-72522d57c5c4> in <module>
# ----> 1 int('hetvi10')
#
# ValueError: invalid literal for int() with base 10: 'hetvi10'

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-0106664d39e8> in <module>
# ----> 1 5/0
#
# ZeroDivisionError: division by zero
